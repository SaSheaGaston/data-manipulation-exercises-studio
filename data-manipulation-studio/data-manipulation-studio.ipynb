# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit the data set from our last studio. If you recall, California farmers were looking for advice on growing pumpkins. We will use the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# A **terminal market** is a central site, often in a metropolitan area, that serves as an assembly and trading place for commodities. Terminal markets for agricultural commodities are usually at or near major transportation hubs. [Definition Source](https://en.wikipedia.org/wiki/Terminal_market#:~:text=A%20terminal%20market%20is%20a,or%20near%20major%20transportation%20hubs)
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!

import pandas as pd
import numpy as np

baltimore = pd.read_csv("C:/Users/Sa Shea/data-analysis-projects-SaSheaG/data-manipulation-exercises-studio/data-manipulation-studio/dataset/baltimore_9-24-2016_9-30-2017.csv")
boston = pd.read_csv("C:/Users/Sa Shea/data-analysis-projects-SaSheaG/data-manipulation-exercises-studio/data-manipulation-studio/dataset/boston_9-24-2016_9-30-2017.csv")
new_york = pd.read_csv("C:/Users/Sa Shea/data-analysis-projects-SaSheaG/data-manipulation-exercises-studio/data-manipulation-studio/dataset/new-york_9-24-2016_9-30-2017.csv")
philadelphia = pd.read_csv("C:/Users/Sa Shea/data-analysis-projects-SaSheaG/data-manipulation-exercises-studio/data-manipulation-studio/dataset/philadelphia_9-24-2016_9-30-2017.csv")

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data related to San Francisco. Pull up your notebook from the last lesson and use it as a reference to clean up these new dataframes.
#
# **Recommended cleaning steps:**
# 1. Handle missing values in the `Type` column (fill with "Conventional" if needed)
# 2. Drop irrelevant columns such as `Grade` (only applies to canned pumpkins)
# 3. Drop columns with high percentages of missing data that aren't needed for analysis
# 4. Check for and address any other data quality issues you notice

# %%
baltimore.head()
# Out:
#   Commodity Name  City Name          Type       Package      Variety  \
# 0       PUMPKINS  BALTIMORE  Conventional  24 inch bins          NaN
# 1       PUMPKINS  BALTIMORE  Conventional  24 inch bins          NaN
# 2       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
# 3       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
# 4       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN TYPE
#
#   Sub Variety        Date  Low Price  High Price  Mostly Low  ...  Color  \
# 0         NaN  04/29/2017        270       280.0         270  ...    NaN
# 1         NaN  05/06/2017        270       280.0         270  ...    NaN
# 2         NaN  09/24/2016        160       160.0         160  ...    NaN
# 3         NaN  09/24/2016        160       160.0         160  ...    NaN
# 4         NaN  11/05/2016         90       100.0          90  ...    NaN
#
#   Environment  Unit of Sale Quality Condition  Appearance Storage  Crop  \
# 0         NaN           NaN     NaN       NaN         NaN     NaN   NaN
# 1         NaN           NaN     NaN       NaN         NaN     NaN   NaN
# 2         NaN           NaN     NaN       NaN         NaN     NaN   NaN
# 3         NaN           NaN     NaN       NaN         NaN     NaN   NaN
# 4         NaN           NaN     NaN       NaN         NaN     NaN   NaN
#
#    Repack  Trans Mode
# 0       E         NaN
# 1       E         NaN
# 2       N         NaN
# 3       N         NaN
# 4       N         NaN
#
# [5 rows x 24 columns]

# %%
# Clean your data here!
# 1 change missing values in Type column to "Conventional"
# example: data["Type"] = data["Type"].fillna("Conventional")

baltimore["Type"] = baltimore["Type"].fillna("Conventional")
boston["Type"] = boston["Type"].fillna("Conventional")
new_york["Type"] = new_york["Type"].fillna("Conventional")
philadelphia["Type"] = philadelphia["Type"].fillna("Conventional")

# %%
#check
baltimore
# Out:
#     Commodity Name  City Name          Type             Package      Variety  \
# 0         PUMPKINS  BALTIMORE  Conventional        24 inch bins          NaN
# 1         PUMPKINS  BALTIMORE  Conventional        24 inch bins          NaN
# 2         PUMPKINS  BALTIMORE  Conventional        24 inch bins  HOWDEN TYPE
# 3         PUMPKINS  BALTIMORE  Conventional        24 inch bins  HOWDEN TYPE
# 4         PUMPKINS  BALTIMORE  Conventional        24 inch bins  HOWDEN TYPE
# ..             ...        ...           ...                 ...          ...
# 148       PUMPKINS  BALTIMORE  Conventional  1/2 bushel cartons    MINIATURE
# 149       PUMPKINS  BALTIMORE  Conventional  1/2 bushel cartons    MINIATURE
# 150       PUMPKINS  BALTIMORE  Conventional  1/2 bushel cartons    MINIATURE
# 151       PUMPKINS  BALTIMORE  Conventional  1/2 bushel cartons    MINIATURE
# 152       PUMPKINS  BALTIMORE  Conventional  1/2 bushel cartons    MINIATURE
#
#     Sub Variety  Grade        Date  Low Price  High Price  ...   Color  \
# 0           NaN    NaN  04/29/2017        270       280.0  ...     NaN
# 1           NaN    NaN  05/06/2017        270       280.0  ...     NaN
# 2           NaN    NaN  09/24/2016        160       160.0  ...     NaN
# 3           NaN    NaN  09/24/2016        160       160.0  ...     NaN
# 4           NaN    NaN  11/05/2016         90       100.0  ...     NaN
# ..          ...    ...         ...        ...         ...  ...     ...
# 148         NaN    NaN  09/30/2017         18        18.0  ...  ORANGE
# 149         NaN    NaN  09/30/2017         18        18.0  ...  ORANGE
# 150  ROUND TYPE    NaN  09/24/2016         15        15.0  ...     NaN
# 151  ROUND TYPE    NaN  10/01/2016         15        15.0  ...     NaN
# 152  ROUND TYPE    NaN  10/08/2016         15        15.0  ...     NaN
#
#      Environment Unit of Sale  Quality Condition Appearance  Storage Crop  \
# 0            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 1            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 2            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 3            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 4            NaN          NaN      NaN       NaN        NaN      NaN  NaN
# ..           ...          ...      ...       ...        ...      ...  ...
# 148          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 149          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 150          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 151          NaN          NaN      NaN       NaN        NaN      NaN  NaN
# 152          NaN          NaN      NaN       NaN        NaN      NaN  NaN
#
#      Repack  Trans Mode
# 0         E         NaN
# 1         E         NaN
# 2         N         NaN
# 3         N         NaN
# 4         N         NaN
# ..      ...         ...
# 148       N         NaN
# 149       N         NaN
# 150       N         NaN
# 151       N         NaN
# 152       N         NaN
#
# [153 rows x 25 columns]

# %%
# 2. Drop irrelevant columns such as "Grade"


boston = boston.drop(["Grade"], axis=1) 
new_york = new_york.drop(["Grade"], axis=1) 
philadelphia = philadelphia.drop(["Grade"], axis=1)

# %%
boston
# Out:
#     Commodity Name City Name          Type             Package      Variety  \
# 0         PUMPKINS    BOSTON  Conventional        36 inch bins  HOWDEN TYPE
# 1         PUMPKINS    BOSTON  Conventional        36 inch bins  HOWDEN TYPE
# 2         PUMPKINS    BOSTON  Conventional        36 inch bins  HOWDEN TYPE
# 3         PUMPKINS    BOSTON  Conventional        36 inch bins  HOWDEN TYPE
# 4         PUMPKINS    BOSTON  Conventional        36 inch bins  HOWDEN TYPE
# ..             ...       ...           ...                 ...          ...
# 347       PUMPKINS    BOSTON  Conventional  1/2 bushel cartons    MINIATURE
# 348       PUMPKINS    BOSTON  Conventional  1/2 bushel cartons    MINIATURE
# 349       PUMPKINS    BOSTON  Conventional  1/2 bushel cartons    MINIATURE
# 350       PUMPKINS    BOSTON  Conventional  1/2 bushel cartons    MINIATURE
# 351       PUMPKINS    BOSTON  Conventional  1/2 bushel cartons    MINIATURE
#
#     Sub Variety        Date  Low Price  High Price  Mostly Low  ...   Color  \
# 0           NaN  09/24/2016        160         200         165  ...  ORANGE
# 1           NaN  09/24/2016        160         200         165  ...  ORANGE
# 2           NaN  09/24/2016        160         200         165  ...  ORANGE
# 3           NaN  09/24/2016        160         200         165  ...  ORANGE
# 4           NaN  09/24/2016        160         180         165  ...  ORANGE
# ..          ...         ...        ...         ...         ...  ...     ...
# 347  ROUND TYPE  10/22/2016         15          18          15  ...  ORANGE
# 348  ROUND TYPE  10/29/2016         15          18          15  ...   WHITE
# 349  ROUND TYPE  10/29/2016         15          18          15  ...  ORANGE
# 350  ROUND TYPE  11/05/2016         15          18          15  ...   WHITE
# 351  ROUND TYPE  11/05/2016         15          18          15  ...  ORANGE
#
#     Environment Unit of Sale Quality Condition  Appearance Storage  Crop  \
# 0           NaN          NaN     NaN       NaN         NaN     NaN   NaN
# 1           NaN          NaN     NaN       NaN         NaN     NaN   NaN
# 2           NaN          NaN     NaN       NaN         NaN     NaN   NaN
# 3           NaN          NaN     NaN       NaN         NaN     NaN   NaN
# 4           NaN          NaN     NaN       NaN         NaN     NaN   NaN
# ..          ...          ...     ...       ...         ...     ...   ...
# 347         NaN          NaN     NaN       NaN         NaN     NaN   NaN
# 348         NaN          NaN     NaN       NaN         NaN     NaN   NaN
# 349         NaN          NaN     NaN       NaN         NaN     NaN   NaN
# 350         NaN          NaN     NaN       NaN         NaN     NaN   NaN
# 351         NaN          NaN     NaN       NaN         NaN     NaN   NaN
#
#      Repack  Trans Mode
# 0         N         NaN
# 1         N         NaN
# 2         N         NaN
# 3         N         NaN
# 4         N         NaN
# ..      ...         ...
# 347       N         NaN
# 348       N         NaN
# 349       N         NaN
# 350       N         NaN
# 351       N         NaN
#
# [352 rows x 24 columns]

# %%
# 3. Drop columns with high percentage of missing data

for col in baltimore.columns:
    pct_missing = np.mean(baltimore[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 0%
# Package - 0%
# Variety - 1%
# Sub Variety - 84%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 3%
# Origin District - 100%
# Item Size - 16%
# Color - 80%
# Environment - 100%
# Unit of Sale - 84%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
#for boston 

for col in boston.columns:
    pct_missing = np.mean(boston[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 0%
# Package - 0%
# Variety - 0%
# Sub Variety - 92%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 81%
# Item Size - 1%
# Color - 14%
# Environment - 100%
# Unit of Sale - 87%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
# for new york

for col in new_york.columns:
    pct_missing = np.mean(new_york[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 0%
# Package - 0%
# Variety - 0%
# Sub Variety - 84%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 87%
# Item Size - 7%
# Color - 81%
# Environment - 100%
# Unit of Sale - 78%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
# for philadelphia

for col in philadelphia.columns:
    pct_missing = np.mean(philadelphia[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 0%
# Package - 0%
# Variety - 0%
# Sub Variety - 79%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 100%
# Item Size - 21%
# Color - 100%
# Environment - 100%
# Unit of Sale - 81%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
# I will drop the environment column from each dataframe because all values are missing

baltimore = baltimore.drop(["Environment"], axis= 1)
boston = boston.drop(["Environment"], axis=1)
new_york = new_york.drop(["Environment"], axis=1) 
philadelphia = philadelphia.drop(["Environment"], axis=1)

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!

combined = (
    baltimore.merge(boston, on="Type", how="inner").merge(new_york, on="Type", how="inner").merge(philadelphia, on="Type", how="inner")
)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[23], line 4
#       1 # Combine the four dataframes into one!
#       3 combined = (
# ----> 4     baltimore.merge(boston, on="Type", how="inner").merge(new_york, on="Type", how="inner").merge(philadelphia, on="Type", how="inner")
#       5 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:10859, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10840 @Substitution("")
#   10841 @Appender(_merge_doc, indents=2)
#   10842 def merge(
#    (...)  10855     validate: MergeValidate | None = None,
#   10856 ) -> DataFrame:
#   10857     from pandas.core.reshape.merge import merge
# > 10859     return merge(
#   10860         self,
#   10861         right,
#   10862         how=how,
#   10863         on=on,
#   10864         left_on=left_on,
#   10865         right_on=right_on,
#   10866         left_index=left_index,
#   10867         right_index=right_index,
#   10868         sort=sort,
#   10869         suffixes=suffixes,
#   10870         copy=copy,
#   10871         indicator=indicator,
#   10872         validate=validate,
#   10873     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)    182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\merge.py:848, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     840 llabels, rlabels = _items_overlap_with_suffix(
#     841     self.left._info_axis, self.right._info_axis, self.suffixes
#     842 )
#     844 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     845     # Pinning the index here (and in the right code just below) is not
#     846     #  necessary, but makes the `.take` more performant if we have e.g.
#     847     #  a MultiIndex for left.index.
# --> 848     lmgr = left._mgr.reindex_indexer(
#     849         join_index,
#     850         left_indexer,
#     851         axis=1,
#     852         copy=False,
#     853         only_slice=True,
#     854         allow_dups=True,
#     855         use_na_proxy=True,
#     856     )
#     857     left = left._constructor_from_mgr(lmgr, axes=lmgr.axes)
#     858 left.index = join_index
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:707, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     699     new_blocks = self._slice_take_blocks_ax0(
#     700         indexer,
#     701         fill_value=fill_value,
#     702         only_slice=only_slice,
#     703         use_na_proxy=use_na_proxy,
#     704     )
#     705 else:
#     706     new_blocks = [
# --> 707         blk.take_nd(
#     708             indexer,
#     709             axis=1,
#     710             fill_value=(
#     711                 fill_value if fill_value is not None else blk.fill_value
#     712             ),
#     713         )
#     714         for blk in self.blocks
#     715     ]
#     717 new_axes = list(self.axes)
#     718 new_axes[axis] = new_axis
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\blocks.py:1373, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1370     allow_fill = True
#    1372 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1373 new_values = algos.take_nd(
#    1374     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1375 )
#    1377 # Called from three places in managers, all of which satisfy
#    1378 #  these assertions
#    1379 if isinstance(self, ExtensionBlock):
#    1380     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1381     #  algos.take_nd call above.
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 38.4 GiB for an array with shape (15, 343816704) and data type float64

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of **unit of sale** in the Northeast region?
# 2. For the Northeast region, what is the total count of transactions (rows) for each pumpkin variety that came into terminal markets for the year?

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.

# %%
# Put your code here to find the total count of transactions for each variety in the Northeast region.

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for a different region! Choose either:
# - **Midwest**: Chicago, Detroit, and St. Louis
# - **Southeast**: Atlanta, Columbia, and Miami
#
# Load, clean, and combine the data for your chosen region, then calculate:
# 1. The mean low and high prices for each type of unit of sale
# 2. The total count of transactions for each pumpkin variety

# %%
# Try the bonus mission if you have time!
